# %% [markdown]
# # Project Scope: Life Expectancy and GDP
#
# ## Goals
# - Analyze the relationship between **GDP** and **Life Expectancy** for six countries.
# - Answer key questions:
#   - Is there a positive correlation between GDP and life expectancy?
#   - How has life expectancy changed over time in these countries?
#   - Are there exceptions (countries with high GDP but relatively low life expectancy, or the opposite)?
#
# ## Data
# - Source: World Health Organization (WHO) and World Bank (provided in `all_data.csv`).
# - Main columns: `Country`, `Year`, `GDP`, `Life Expectancy`.
# - Preparation steps:
#   - Check for missing values.
#   - Ensure numerical columns (GDP, Year, Life Expectancy) are properly formatted.
#
# ## Analysis
# - Descriptive statistics (mean, min, max, distributions).
# - Visualizations:
#   - Scatter plot: GDP vs. Life Expectancy.
#   - Line plots: Life Expectancy over time by country.
# - Insights:
#   - Identify overall trends and correlations.
#   - Highlight differences and anomalies between countries.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("all_data.csv")

# Take a look at the first few rows 
df.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB

# %%
df.describe()
# Out:
#               Year  Life expectancy at birth (years)           GDP
# count    96.000000                         96.000000  9.600000e+01
# mean   2007.500000                         72.789583  3.880499e+12
# std       4.633971                         10.672882  5.197561e+12
# min    2000.000000                         44.300000  4.415703e+09
# 25%    2003.750000                         74.475000  1.733018e+11
# 50%    2007.500000                         76.750000  1.280220e+12
# 75%    2011.250000                         78.900000  4.067510e+12
# max    2015.000000                         81.000000  1.810000e+13

# %%
df = df.rename(columns={
    "Life expectancy at birth (years)": "Life_Expectancy"
})

# %%
# Summary stats grouped by country
print(df.groupby("Country")["Life_Expectancy"].mean())
print(df.groupby("Country")["GDP"].mean())
# Out:
# Country
# Chile                       78.94375
# China                       74.26250
# Germany                     79.65625
# Mexico                      75.71875
# United States of America    78.06250
# Zimbabwe                    50.09375
# Name: Life_Expectancy, dtype: float64
# Country
# Chile                       1.697888e+11
# China                       4.957714e+12
# Germany                     3.094776e+12
# Mexico                      9.766506e+11
# United States of America    1.407500e+13
# Zimbabwe                    9.062580e+09
# Name: GDP, dtype: float64

# %% [markdown]
# ### Insights
# - Most countries have life expectancy between 74–80 years, except Zimbabwe which is significantly lower.
# - GDP levels vary widely, with the USA and China far ahead.
# - There seems to be a general correlation between higher GDP and higher life expectancy, though not always proportional (e.g., USA vs. Chile).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.lineplot(x="Year", y="Life_Expectancy", hue="Country", data=df, marker="o")
plt.title("Life Expectancy over Time (2000-2015)")
plt.show()

# %% [markdown]
# **Life Expectancy over Time (2000–2015)**
#    Most countries show a steady increase in life expectancy, while Zimbabwe experienced a sharp rise after 2005.

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Year", y="GDP", hue="Country", data=df, marker="o")
plt.title("GDP over Time (2000-2015)")
plt.show()

# %% [markdown]
# **GDP over Time (2000–2015)**
#    China and the United States show significant GDP growth, while other countries have slower, smaller growth trends.

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x="GDP", y="Life_Expectancy", hue="Country", data=df)
plt.title("GDP vs Life Expectancy")
plt.show()

# %% [markdown]
# **GDP vs Life Expectancy**
#    There is a positive correlation: countries with higher GDP tend to have higher life expectancy, with Zimbabwe as an outlier.

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["Life_Expectancy"], bins=15, kde=True)
plt.title("Distribution of Life Expectancy")
plt.show()

# %% [markdown]
# **Distribution of Life Expectancy**
#    Most values are concentrated between 75–80 years, with lower values mainly from Zimbabwe.

# %% [markdown]
# ## Conclusion
#
# Throughout this project, I practiced the full data analysis workflow:
# - Loading and cleaning real-world data with **pandas**.
# - Exploring and summarizing the dataset using descriptive statistics.
# - Visualizing trends with **Matplotlib** and **Seaborn**.
# - Interpreting results and writing insights.
#
# ### Key Findings
# - **Life Expectancy** has generally increased between 2000–2015 in all six countries.
# - **GDP** has also increased over time, especially in the United States and China.
# - There is a clear **positive correlation** between GDP and life expectancy, although the relationship is not always proportional (e.g., Chile vs. USA).
# - **Zimbabwe** stands out as an outlier with much lower life expectancy and GDP compared to the other nations, but it showed noticeable improvement after 2005.
#
# ### Takeaways
# - Economic growth (GDP) tends to be associated with higher life expectancy, but social, healthcare, and policy factors also play a role.
# - Data visualization is a powerful way to communicate these findings clearly.
# - This project demonstrates the importance of combining statistics, visualization, and narrative to tell a compelling data story.
